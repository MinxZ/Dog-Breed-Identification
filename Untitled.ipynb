# %%
import os
import random
from datetime import datetime

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import SVG
from keras import backend as K
from keras.applications import *
from keras.applications.inception_v3 import preprocess_input
from keras.applications.vgg16 import (VGG16, decode_predictions)
from keras.callbacks import EarlyStopping, TensorBoard
from keras.layers import *
from keras.models import *
from keras.optimizers import *
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import *
from keras.utils.vis_utils import model_to_dot
from tqdm import tqdm

# %%
# Loading Datasets

df = pd.read_csv('../dog_breed_datasets/labels.csv')
df.head()

n = len(df)
breed = set(df['breed'])
n_class = len(breed)
class_to_num = dict(zip(breed, range(n_class)))
num_to_class = dict(zip(range(n_class), breed))

width = 224
X = np.zeros((n, width, width, 3), dtype=np.uint8)
y = np.zeros((n, n_class), dtype=np.uint8)
for i in tqdm(range(n)):
    X[i] = cv2.resize(
        cv2.imread('../dog_breed_datasets/train/%s.jpg' % df['id'][i]),
        (width, width))
    y[i][class_to_num[df['breed'][i]]] = 1
# Out:
# 100%|██████████| 10222/10222 [00:24<00:00, 421.81it/s]

# %%
dvi = int(X.shape[0]*0.9)
y.shape
# Out:
# (10222, 120)

# %%
x_train = X[:dvi,:,:,:]
x_val = X[dvi:,:,:,:]
y_train = y[:dvi,:]
y_val = y[:dvi,:]

# %%
def get_features(MODEL, data=X):
    cnn_model = MODEL(
        include_top=False, input_shape=(width, width, 3), weights='imagenet')

    inputs = Input((width, width, 3))
    x = inputs
    x = Lambda(preprocess_input, name='preprocessing')(x)
    x = cnn_model(x)
    x = GlobalAveragePooling2D()(x)
    cnn_model = Model(inputs, x)

    features = cnn_model.predict(data, batch_size=32, verbose=1)
    return features
print('Start computing VGG16: ')
# features = get_features(VGG16, X)
features_train = get_features(VGG16, x_train)
features_val = get_features(VGG16, x_val)
# Out:
# Start computing VGG16:
# ...
# 1023/1023 [==============================] - 7s 7ms/step

# %%
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# Training models
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(n_class, activation='softmax', name='predictions')(x)
top_model = Model(inputs, x)
# model.load_weights('fc_s2.h5', by_name=True)
top_model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
h = top_model.fit_generator(features, y, batch_size=128, epochs=150, validation_split=0.1)
model.save('fc.h5','w')

# %%
# Models visualization

# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# Training preprocess visualization

import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(1, 2, 2)
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['acc', 'val_acc'])
plt.ylabel('acc')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,u'epoch')

# %%
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

inputs = Input((width, width, 3))
x = inputs
x = Lambda(preprocess_input, name='preprocessing')(x)
cnn_model = VGG16(include_top=False, input_shape=(width, width, 3), weights='imagenet')
x = cnn_model(x)
x = GlobalAveragePooling2D()(x)
x = Dense(n_class, activation='softmax', name='predictions')(x)
model = Model(inputs=inputs, outputs=x)

for layer in model.layers[:6]:
    layer.trainable = False
model.load_weights('fc.h5', by_name=True)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

h = model.fit(X, y, batch_size=32, epochs=10, validation_split=0.1)



# model.compile(loss='categorical_crossentropy',
#               optimizer=SGD(lr=0.01, momentum=0.9, nesterov=True),
#               metrics=['accuracy'])

# early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')

# history = model.fit_generator(
#     datagen.flow(X, y, batch_size=32),
#     steps_per_epoch=len(X) / 32, 
#     epochs=20, 
#     verbose = 1,
#     shuffle=False)
#    callbacks=[early_stopping]
#     validation_split=0.1,
               
model.save('VGG16.h5','w')
# Out:
# Train on 9199 samples, validate on 1023 samples
# Epoch 1/10
# 9199/9199 [==============================] - 75s 8ms/step - loss: 0.8489 - acc: 0.8389 - val_loss: 1.6248 - val_acc: 0.5621
# Epoch 2/10
# 9199/9199 [==============================] - 73s 8ms/step - loss: 0.8489 - acc: 0.8389 - val_loss: 1.6248 - val_acc: 0.5621
# Epoch 3/10
# 1184/9199 [==>...........................] - ETA: 57s - loss: 0.8498 - acc: 0.8370
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-97d9844e83e8> in <module>()
#      20 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#      21
# ---> 22 h = model.fit(X, y, batch_size=32, epochs=10, validation_split=0.1)
#      23
#      24
#
# ...

# %%
# let's visualize layer names and layer indices to see how many layers
# we should freeze:
base_model = VGG16(weights='imagenet', include_top = False)
for i, layer in enumerate(base_model.layers):
   print(i, layer.name)
# Out:
# (0, 'input_46')
# (1, 'block1_conv1')
# (2, 'block1_conv2')
# (3, 'block1_pool')
# (4, 'block2_conv1')
# (5, 'block2_conv2')
# (6, 'block2_pool')
# (7, 'block3_conv1')
# (8, 'block3_conv2')
# (9, 'block3_conv3')
# (10, 'block3_pool')
# (11, 'block4_conv1')
# (12, 'block4_conv2')
# (13, 'block4_conv3')
# (14, 'block4_pool')
# (15, 'block5_conv1')
# (16, 'block5_conv2')
# (17, 'block5_conv3')
# (18, 'block5_pool')
